# %%
import pandas as pd
import recommend_ui_functions

# %%
movies = pd.read_csv("ui_movies_dummy.csv")

# %%
movies[movies["title"].astype(str).str.contains("Avengers")]
# Out:
#       imdb_title_id                             title  year date_published  \
# 2256      tt0118661    The Avengers - Agenti speciali  1998     1998-10-30
# 7542      tt1089539             The Avengers(English)  2012     2012-04-25
# 7543      tt1453799             The Avengers(Russian)  2012     2012-04-25
# 7544      tt1808811               The Avengers(Hindi)  2012     2012-04-25
# 12406     tt1018963  Avengers: Age of Ultron(English)  2015     2015-04-22
# 14457     tt4154756            Avengers: Infinity War  2018     2018-04-25
# 14458     tt1120809        Avengers: Endgame(English)  2019     2019-04-24
# 14459     tt1904510         Avengers: Endgame(German)  2019     2019-04-24
# 15981     tt6172666   Avengers of Justice: Farce Wars  2018           2018
#
#                            genre language country                  director  \
# 2256   Action, Adventure, Sci-Fi  English     USA       Jeremiah S. Chechik
# ...

# %% [markdown]
# Recommendation for movie title id: tt1089539 using cosine similarity

# %%
recommend_ui_functions.recommendation_cosine_similarity("tt1089539")[["imdb_title_id", "title", "genre", "language", "description", "weighted_average_vote"]]
# Out:
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:37: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
#       imdb_title_id                                   title  \
# 1377      tt1580582                   Pulp Fiction(English)
# 1247      tt0109830                            Forrest Gump
# 2940      tt0133093                                  Matrix
# 2678      tt1472837                Il miglio verde(English)
# 526       tt1837252    Il silenzio degli innocenti(English)
# 1758      tt0114369                                   Seven
# ...

# %% [markdown]
# Recommendation for movie title id: tt1089539 using euclidean distance metrics

# %%
from sklearn.metrics.pairwise import euclidean_distances

recommend_ui_functions.recommendation_distance_metrics("tt1089539", euclidean_distances)[["imdb_title_id", "title", "genre", "language", "description", "weighted_average_vote"]]
# Out:
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:91: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:99: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
#       imdb_title_id                                      title  \
# 8316     tt10765852  Metallica and San Francisco Symphony S&M2
# 8492     tt11166002                            Stanley Stanton
# 13786     tt3505898                                     Strive
# 15779     tt5891144                          Spies Are Forever
# 14324     tt3978706          These Words Must Be on Your Heart
# ...

# %% [markdown]
# Recommendation for movie title id: tt1089539 using manhattan distance metrics

# %%
from sklearn.metrics.pairwise import manhattan_distances

recommend_ui_functions.recommendation_distance_metrics("tt1089539", manhattan_distances)[["imdb_title_id", "title", "genre", "language", "description", "weighted_average_vote"]]
# Out:
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:91: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:99: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
#       imdb_title_id                                              title  \
# 9898      tt1508669                                      Hopeful Notes
# 8491     tt11164090                                The Moving on Phase
# 1414      tt0111161                               Le ali della libert�
# 15904     tt6074834                                     Delaware Shore
# 11806     tt2170667                                             Wheels
# ...

# %% [markdown]
# Recommendation for movie title id: tt1089539 using manhattan distance metrics

# %%
recommend_ui_functions.recommendation_pearson("tt1089539")[["imdb_title_id", "title", "genre", "language", "description", "weighted_average_vote"]]
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\Dell\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\Dell\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\Dell\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# ...

# %% [markdown]
# Recommendation for movie title id: tt1089539 using overlapping of all the recommendations

# %%
recommend_ui_functions.recommendation_of_movie("tt1089539")[["imdb_title_id", "title", "genre", "language", "description", "weighted_average_vote"]]
# Out:
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:37: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:91: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
# ...

# %%
movies[movies["imdb_title_id"].astype(str).str.contains("|".join(["tt1089539", "tt1153858", "tt6567472", "tt0441773", "tt1849487"]))]
# Out:
#       imdb_title_id                         title  year date_published  \
# 992       tt1849487        Jurassic Park(English)  1993     1993-09-17
# 2069      tt1153858  Mission: Impossible(English)  1996     1996-09-13
# 6302      tt0441773                 Kung Fu Panda  2008     2008-08-29
# 7542      tt1089539         The Avengers(English)  2012     2012-04-25
# 16193     tt6567472                    Death Game  2017     2017-02-22
#
#                               genre language country  \
# 992       Action, Adventure, Sci-Fi  English     USA
# 2069    Action, Adventure, Thriller  English     USA
# 6302   Animation, Action, Adventure  English     USA
# 7542      Action, Adventure, Sci-Fi  English     USA
# 16193                      Thriller  English     USA
#
#                            director                              writer  \
# 992                Steven Spielberg  Michael Crichton, Michael Crichton
# ...

# %%
recommend_ui_functions.recommendation_with_list_of_movies(["tt1089539", "tt1153858", "tt6567472", "tt0441773", "tt1849487"])
# Out:
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:37: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
# C:\Users\Dell\OneDrive\Desktop\DePaul\MachineLearning\Project\project_document\recommend_ui_functions.py:91: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   language_movie = language_movie[movies["imdb_title_id"].astype(str).str.contains(
# ...
